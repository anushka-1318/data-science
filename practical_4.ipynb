# %% [markdown]
# <a href="https://colab.research.google.com/github/anushka-1318/data-science/blob/main/practical_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
data = np.random.normal(50, 10, 1000)

# Plot histogram
plt.hist(data, bins=30)
plt.title("Normal Distribution Histogram")
plt.xlabel("Values")
plt.ylabel("Frequency")
plt.show()

# %%
mean = np.mean(data)
median = np.median(data)
variance = np.var(data)
std_dev = np.std(data)

print("Mean:", mean)
print("Median:", median)
print("Variance:", variance)
print("Standard Deviation:", std_dev)
# Out:
# Mean: 49.96966833957714
# Median: 49.69849950739313
# Variance: 105.2140160768176
# Standard Deviation: 10.257388365311007

# %%
toss = np.random.choice(['H', 'T'], 1000)

heads = np.count_nonzero(toss == 'H')
tails = np.count_nonzero(toss == 'T')

print("Heads:", heads)
print("Tails:", tails)
print("Probability of Head:", heads/1000)
print("Probability of Tail:", tails/1000)
# Out:
# Heads: 498
# Tails: 502
# Probability of Head: 0.498
# Probability of Tail: 0.502
